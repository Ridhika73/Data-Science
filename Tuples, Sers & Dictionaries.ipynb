# %%
my_tuple = (1,'a',3)
print(my_tuple)
# Out:
# (1, 'a', 3)

# %%
type(my_tuple)
# Out:
# tuple

# %%
another_tuple = ('one',2,4.53,'asbc')
another_tuple
# Out:
# ('one', 2, 4.53, 'asbc')

# %%
my_list =[1]
type(my_list)
# Out:
# list

# %%
(my_tuple) =(1,)
type (my_tuple)
# Out:
# tuple

# %%
(my_tuple)= 1,2,3
type((my_tuple))
# Out:
# tuple

# %%
(my_tuple) =(1,2,3,4)
len((my_tuple))
# Out:
# 4

# %%
print(another_tuple)
# Out:
# ('one', 2, 4.53, 'asbc')

# %%
(another_tuple)[0]
# Out:
# 'one'

# %%
another_tuple[3]
# Out:
# 'asbc'

# %%
another_tuple[-1]
# Out:
# 'asbc'

# %%
another_tuple[-3]
# Out:
# 2

# %%
print(another_tuple)
# Out:
# ('one', 2, 4.53, 'asbc')

# %%
another_tuple[1:3]
# Out:
# (2, 4.53)

# %%
another_tuple[2:]
# Out:
# (4.53, 'asbc')

# %%
another_tuple[:6]
# Out:
# ('one', 2, 4.53, 'asbc')

# %%
another_tuple[-4:]
# Out:
# ('one', 2, 4.53, 'asbc')

# %%
len(another_tuple)
# Out:
# 4

# %%
my_tuple = (1,2,3,4,5,6,1,1,2)
my_tuple.index(2)
# Out:
# 1

# %%
my_tuple.count(2)
# Out:
# 2

# %%
my_tuple.count(1)
# Out:
# 3

# %%
print(my_tuple)
# Out:
# (1, 2, 3, 4, 5, 6, 1, 1, 2)

# %%
my_tuple[0]
# Out:
# 1

# %%
my_tuple[0] = 'change'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-1113c19e61ee> in <cell line: 0>()
# ----> 1 my_tuple[0] = 'change'
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_list = [5,7,9,3,2]
my_list[0] =1
my_list
# Out:
# [1, 7, 9, 3, 2]

# %%
empty_set = set ()
type(empty_set)
# Out:
# set

# %%
non_empty_set = {1,6,4,'abc'}
type(non_empty_set )
# Out:
# set

# %%
my_object={}
type( my_object)
# Out:
# dict

# %%
my_set = set ()
type (my_set)
# Out:
# set

# %%
my_list = [1,1,2,2,3,4,5,6,1,1]
my_set = set (my_list)
my_set
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
my_set = {1,2,(3,4)}
my_set = {(2,3),1,2}
my_set
# Out:
# {(2, 3), 1, 2}

# %%
my_set=set()
my_set.add('a')
my_set
# Out:
# {'a'}

# %%
my_set.add(2)
print(my_set)
# Out:
# {2, 'a'}

# %%
my_set = {5,7,9,3}
my_set.update([2,3,4])
print(my_set)
# Out:
# {2, 3, 4, 5, 7, 9}

# %%
non_empty_set = {1,5,6,73,2}
non_empty_set.remove(5)
non_empty_set
# Out:
# {1, 2, 6, 73}

# %%
A= {1,2,3,4,5}
B= {4,5,6,7,8}
A.union(B)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
A
# Out:
# {1, 2, 3, 4, 5}

# %%
A|B
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
A= {1,2,3,4,5}
B= {4,5,6,7,8}
A.intersection (B)
# Out:
# {4, 5}

# %%
A&B
# Out:
# {4, 5}

# %%
A= {1,2,3,4,5}
B= {4,5,6,7,8}
A.difference(B)
# Out:
# {1, 2, 3}

# %%
A-B
# Out:
# {1, 2, 3}

# %%
B.difference(A)
# Out:
# {6, 7, 8}

# %%
B-A
# Out:
# {6, 7, 8}

# %%
A= {1,2,3,4,5}
B= {4,5,6,7,8}
A.symmetric_difference(B)
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
A^B
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
marvel_dict = {'Name':'Thor','Place':'Asgard','Weapon':'Hammer',1:2,3:'power','alibies':'ironman'}
marvel_dict ['Place']
# Out:
# 'Asgard'

# %%
type(marvel_dict )
# Out:
# dict

# %%
marvel_dict ['Name']
# Out:
# 'Thor'

# %%
marvel_dict ['Weapon']
# Out:
# 'Hammer'

# %%
marvel_dict ['alibies']
# Out:
# 'ironman'

# %%
marvel_dict.keys()
# Out:
# dict_keys(['Name', 'Place', 'Weapon', 1, 3, 'alibies'])

# %%
list(marvel_dict.keys())
# Out:
# ['Name', 'Place', 'Weapon', 1, 3, 'alibies']

# %%
print(marvel_dict )
# Out:
# {'Name': 'Thor', 'Place': 'Asgard', 'Weapon': 'Hammer', 1: 2, 3: 'power', 'alibies': 'ironman'}

# %%
list(marvel_dict.values())
# Out:
# ['Thor', 'Asgard', 'Hammer', 2, 'power', 'ironman']

# %%
list(marvel_dict.items())
# Out:
# [('Name', 'Thor'),
#  ('Place', 'Asgard'),
#  ('Weapon', 'Hammer'),
#  (1, 2),
#  (3, 'power'),
#  ('alibies', 'ironman')]

# %%
marvel_dict.get('Place')
# Out:
# 'Asgard'

# %%
employee_dict = {'Name':'Sanket','skills':['Python','Machine Learning ','Deep Learning'],'Band':6.0}
len(employee_dict.keys())
# Out:
# 3

# %%
employee_dict['skills']
# Out:
# ['Python', 'Machine Learning ', 'Deep Learning']

# %%
employee_dict['skills'][0].upper()
# Out:
# 'PYTHON'

# %%
employee_dict['designation'] = 'Senior Data Scientist'
employee_dict
# Out:
# {'Name': 'Sanket',
#  'skills': ['Python', 'Machine Learning ', 'Deep Learning'],
#  'Band': 6.0,
#  'designation': 'Senior Data Scientist'}

# %%
employee_dict.update({'Salary':'2,00000'})
employee_dict
# Out:
# {'Name': 'Sanket',
#  'skills': ['Python', 'Machine Learning ', 'Deep Learning'],
#  'Band': 6.0,
#  'designation': 'Senior Data Scientist',
#  'Salary': '2,00000'}

# %%
employee_dict.update({'Name':'Varun Saini'})
employee_dict
# Out:
# {'Name': 'Varun Saini',
#  'skills': ['Python', 'Machine Learning ', 'Deep Learning'],
#  'Band': 6.0,
#  'designation': 'Senior Data Scientist',
#  'Salary': '2,00000'}

# %%
country_list = ['India','Australia','United States','England']
country_city = ['New Delhi','Canberra','Washington DC','London']
country_city_list = list (zip (country_list, country_city ))
country_city_list
# Out:
# [('India', 'New Delhi'),
#  ('Australia', 'Canberra'),
#  ('United States', 'Washington DC'),
#  ('England', 'London')]

# %%
dict(country_city_list )
# Out:
# {'India': 'New Delhi',
#  'Australia': 'Canberra',
#  'United States': 'Washington DC',
#  'England': 'London'}

# %%
country_city_tuples =[('India','NewDelhi'),('Australia','Canberra') ,('United States','washington'),('England','London')]
country_city_dict = dict (country_city_tuples )
country_city_dict
# Out:
# {'India': 'NewDelhi',
#  'Australia': 'Canberra',
#  'United States': 'washington',
#  'England': 'London'}

# %%
country_city_dict.pop ('England')
# Out:
# 'London'

# %%
country_city_dict
# Out:
# {'India': 'NewDelhi', 'Australia': 'Canberra', 'United States': 'washington'}

# %%
element_to_pop = country_city_dict.pop('England')
element_to_pop
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-c1878009bf8c> in <cell line: 0>()
# ----> 1 element_to_pop = country_city_dict.pop('England')
#       2 element_to_pop
#
# KeyError: 'England'

# %%
country_city_dict
# Out:
# {'India': 'NewDelhi', 'Australia': 'Canberra', 'United States': 'washington'}

# %%
name = ["Manjeet","Nikhil","Shambhavi"]
marks = [40,50,60,]
mapped = zip (name,marks)
mapped

# %%
print(dict(mapped))
# Out:
# {'Manjeet': 40, 'Nikhil': 50, 'Shambhavi': 60}

# %%
name = ["Manjeet","Nikhil","Shambhavi"]
marks = [40,50,60,]
mapped = zip (name,marks)
print(dict(mapped))
# Out:
# {'Manjeet': 40, 'Nikhil': 50, 'Shambhavi': 60}
