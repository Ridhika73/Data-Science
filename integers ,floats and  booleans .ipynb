# %%
# addition
2+1
# Out:
# 3

# %%
#subtraction
2-5
# Out:
# -3

# %%
#multiplication
2*2
# Out:
# 4

# %%
#division
3/2
# Out:
# 1.5

# %%
# flooor division
7//3
# Out:
# 2

# %%
#exponentiation
2**5
# Out:
# 32

# %%
#modulus
15%6
# Out:
# 3

# %%
#order of operation followed in python
2+10*10+3
# Out:
# 105

# %%
2+10*(10+3)
# Out:
# 132

# %%
#scientific notoation
4E3
# Out:
# 4000.0

# %%
x=5

x
# Out:
# 5

# %%
y=6.4
print (y)
# Out:
# 6.4

# %%
#addition
Z=x+y
print (Z)
# Out:
# 11.4

# %%
#subtraction
Z=x-y
print (Z)
# Out:
# -1.4000000000000004

# %%
#find out the data type of variable z
type (y)
# Out:
# float

# %%
#Multiplication
z=x*y
print (z)
type(z)
# Out:
# 32.0
# float

# %%
#division
z=x/y
print(z)
type(z)
# Out:
# 0.78125
# float

# %%
# floor division
z= x//y
# Remember x=5, y=6.4
print(z)
# Out:
# 0.0

# %%
#set object to be a boolean
boolean_variable= False
type (boolean_variable)
# Out:
# bool

# %%
#show
boolean_variable
# Out:
# False

# %%
2==3
# Out:
# False

# %%
2==0
# Out:
# False

# %%
2!=0
# Out:
# True

# %%
2!=2
# Out:
# False

# %%
a=3
b=2
a>b
# Out:
# True

# %%
a==3
# Out:
# True

# %%
b>4
# Out:
# False

# %%
10<45
# Out:
# True

# %%
4<2
# Out:
# False

# %%
3>=2
# Out:
# True

# %%
4>=4
# Out:
# True

# %%
3<=0
# Out:
# False

# %%
1<=2
# Out:
# True
